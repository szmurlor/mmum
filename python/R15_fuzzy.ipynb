# %%
import numpy as np
from scipy.integrate import trapz
import matplotlib.pyplot as plt

# %%
y= np.arange(0,7,0.1)
mi = (np.exp(-((y-2)/1.5)**2)
      +0.6*np.exp(-((y-4)/0.5)**2));
plt.plot(y,mi); plt.grid()
plt.title('Zadana funkcja rozmyta')
yd=trapz(y,mi*y)/trapz(y,mi)
yd
# Out:
# 2.402802024896918
